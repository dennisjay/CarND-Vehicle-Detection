# %% [markdown]
# ## Load images

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
vehicles = []
non_vehicles = []

for file in glob.glob( 'train_data/vehicles/**/*.png'):
    vehicles.append( file )

for file in glob.glob( 'train_data/non-vehicles/**/*.png'):
    non_vehicles.append( file )

# %% [markdown]
# ## Extract Features

# %% [markdown]
# The features should be extracted for the following images

# %%
# %matplotlib inline
import matplotlib.image as mpimg

car_ex = image.imread(vehicles[0])
noncar_ex = image.imread(non_vehicles[0])

f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 2, figsize=(20,5))
ax1.imshow(car_ex)
ax1.set_title('Car Image', fontsize=30)
ax2.imshow(noncar_ex)
ax2.set_title('Noncar Image', fontsize=30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-dd1a028db559> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2
# ----> 3 car_ex = image.imread(vehicles[0])
#       4 noncar_ex = image.imread(non_vehicles[0])
#       5
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imread'

# %% [markdown]
# While Parameter tuning found the following paramters for optimal accurency:

# %%
from feature_extraction import extract_features, get_hog_features

image = image.imread(vehicles[2])
image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)

orient = 9
pix_per_cell = 8
cell_per_block = 2
spatial_size = (32, 32)
hog_channel='ALL'
nb_bins = 64

channel = image[:,:,0]
features, img = get_hog_features( channel, orient, pix_per_cell, cell_per_block, True, True )

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,5))
ax1.imshow(channel)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(img)
ax2.set_title('Gradient', fontsize=30)
ax3.plot( features )
ax3.set_title('Histogram', fontsize=30)
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %% [markdown]
# Do the following for all images

# %%
params = dict(
    cspace='YUV',
    orient=orient,
    pix_per_cell=pix_per_cell,
    cell_per_block=cell_per_block,
    hog_channel='ALL', 
    nb_bins=nb_bins,
    spatial_size=spatial_size
)

vehicle_features, non_vehicle_features = extract_features( vehicles, **params ), extract_features( non_vehicles, **params )
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %% [markdown]
# ## Train model

# %%
rand_state = 815

X = np.vstack((vehicle_features, non_vehicle_features)).astype(np.float64)
# Fit a per-column scaler
X_scaler = StandardScaler().fit(X)
# Apply the scaler to X
scaled_X = X_scaler.transform(X)

y = np.hstack((np.ones(len(vehicle_features)), np.zeros(len(non_vehicle_features)))) 
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=rand_state)

# %%
svc = LinearSVC()
svc.fit(X_train, y_train)
svc.score(X_test, y_test)
# Out:
# 0.99042792792792789

# %%
from sklearn.externals import joblib

dist = {
    'svc': svc,
    'scaler' : X_scaler,
    'orient' : orient,
    'pix_per_cell' :pix_per_cell,
    'cell_per_block': cell_per_block,
    'hog_channel' : hog_channel,
    'hist_bins' : nb_bins,
    'spatial_size': spatial_size
}

joblib.dump( dist, 'model.pkl')
# Out:
# ['model.pkl']
